# %%
# from support.df_init import init

# df = init()
# df
import pandas as pd

df = pd.read_csv('pp_train.csv')
df
# Out:
#                                  originalTitle  rating  startYear  endYear  \
# 0      Neogenic Nightmare Chapter 3: Hydro-Man       8       1995   1995.0
# 1                                      Looping       6       1982   1982.0
# 2                               Idealnaya para       6       1992   1992.0
# 3                  MasterChef Celebrity México       6       2021      NaN
# 4                                  Seutateueob       8       2020   2020.0
# ...                                        ...     ...        ...      ...
# 16426                                 Caprices       6       1942   1942.0
# 16427                                Haar Jeet       5       1990   1990.0
# 16428                              Kotigobba 3       6       2021   2021.0
# 16429                       Ator l'invincibile       4       1982   1982.0
# 16430                        Anniversary Night      10       2022   2022.0
#
# ...

# %%
og_df = pd.read_csv('dm1_dataset_2425_imdb/train.csv')
og_df
# Out:
#                                  originalTitle   rating  startYear endYear  \
# 0      Neogenic Nightmare Chapter 3: Hydro-Man   (7, 8]       1995      \N
# 1                                      Looping   (5, 6]       1982      \N
# 2                               Idealnaya para   (5, 6]       1992      \N
# 3                  MasterChef Celebrity México   (5, 6]       2021      \N
# 4                                  Seutateueob   (7, 8]       2020    2020
# ...                                        ...      ...        ...     ...
# 16426                                 Caprices   (5, 6]       1942      \N
# 16427                                Haar Jeet   (4, 5]       1990      \N
# 16428                              Kotigobba 3   (5, 6]       2021      \N
# 16429                       Ator l'invincibile   (3, 4]       1982      \N
# 16430                        Anniversary Night  (9, 10]       2022      \N
#
# ...

# %%
df['countryOfOrigin'] = og_df['countryOfOrigin']

# %%
train = df
test = pd.read_csv('pp_test.csv')
og_test = pd.read_csv('dm1_dataset_2425_imdb/test.csv')
test['countryOfOrigin'] = og_test['countryOfOrigin']
test
# Out:
#                                           originalTitle  rating  startYear  \
# 0     Geologist of Animal Collective Performs Live a...      10       2015
# 1                                         Shan gou 1999       5       1999
# 2       The Craftsman: Preserving the Last Higgins Boat       9       2023
# 3                                       Week 3: Tuesday       7       2020
# 4                                             Traumhaus       6       1999
# ...                                                 ...     ...        ...
# 5473                             Parasiz yasamak pahali       8       1994
# 5474                                 Wedding Bell Blues       7       1994
# 5475                    O anthropos pou to 'paize poly!       4       1983
# 5476                             Above Average Presents       7       2012
# 5477                     Omae wa mada Gunma wo shiranai       5       2017
#
# ...

# %%
# train.to_csv('pp_train.csv', index=False)
# test.to_csv('pp_test.csv', index=False)

# %%
test.columns
# Out:
# Index(['originalTitle', 'rating', 'startYear', 'endYear', 'runtimeMinutes',
#        'awardWins', 'numVotes', 'totalImages', 'totalVideos', 'totalCredits',
#        'criticReviewsTotal', 'titleType', 'awardNominationsExcludeWins',
#        'canHaveEpisodes', 'isAdult', 'numRegions', 'userReviewsTotal',
#        'is_Western', 'is_Thriller', 'is_Horror', 'is_Animation', 'is_Family',
#        'is_News', 'is_Sport', 'is_Reality-TV', 'is_Biography', 'is_Sci-Fi',
#        'is_Fantasy', 'is_Documentary', 'is_Talk-Show', 'is_Drama', 'is_Music',
#        'is_Game-Show', 'is_Adventure', 'is_Romance', 'is_Mystery', 'is_Short',
#        'is_Action', 'is_Adult', 'is_History', 'is_Musical', 'is_Crime',
#        'is_Film-Noir', 'is_War', 'is_Comedy', 'fill_runtimeMinutes',
#        'is_from_South America', 'is_from_Oceania', 'is_from_Europe',
#        'is_from_Asia', 'is_from_Africa', 'is_from_North America',
#        'countryOfOrigin', 'countryOfOrigin_freq_enc', 'countryOfOrigin_NA',
# ...

# %%
from support.df_init import init

train = init()
test = init('pp_test.csv')

# %%
# from support.countries_handling import init_countries_trn_tst

# train, test = init_countries_trn_tst(train, test)

# %%
# train.columns

# %%
# train['countryOfOrigin_freq_enc'].unique()

# %%
# train.to_csv('pp_train.csv', index=False)
# test.to_csv('pp_test.csv', index=False)

# %%
from support.imputation import impute_runtime_minutes

imputer = impute_runtime_minutes(train)
train['fill_runtimeMinutes_Bruno'] = imputer(train)
train['fill_runtimeMinutes_Bruno'].unique()
# Out:
# videoGame
# array([2.90e+01,      nan, 9.40e+01, 3.00e+01, 8.00e+01, 3.40e+01,
#        4.50e+01, 6.50e+01, 1.20e+01, 5.20e+01, 4.40e+01, 6.00e+01,
#        9.00e+01, 8.20e+01, 2.10e+01, 1.22e+02, 3.10e+01, 1.70e+01,
#        1.00e+00, 2.30e+01, 9.30e+01, 5.70e+01, 7.40e+01, 8.50e+01,
#        8.30e+01, 7.50e+01, 7.80e+01, 2.80e+01, 1.84e+02, 7.90e+01,
#        2.50e+01, 1.00e+01, 1.08e+02, 4.00e+01, 3.60e+01, 9.80e+01,
#        8.40e+01, 1.10e+02, 4.80e+01, 5.00e+01, 8.90e+01, 4.20e+01,
#        7.10e+01, 4.00e+00, 4.30e+01, 4.10e+01, 6.00e+00, 1.01e+02,
#        7.70e+01, 1.40e+01, 1.60e+01, 9.60e+01, 7.00e+00, 2.40e+01,
#        3.00e+00, 9.20e+01, 2.60e+01, 1.05e+02, 2.00e+01, 8.00e+00,
#        4.90e+01, 1.50e+01, 2.20e+01, 1.43e+02, 1.10e+01, 4.70e+01,
#        9.70e+01, 4.60e+01, 6.20e+01, 5.10e+01, 1.00e+02, 2.70e+01,
#        8.60e+01, 5.80e+01, 3.50e+01, 9.50e+01, 1.03e+02, 7.20e+01,
#        1.80e+01, 6.90e+01, 3.90e+01, 8.70e+01, 9.90e+01, 5.90e+01,
# ...

# %%
test['fill_runtimeMinutes_Bruno'] = imputer(test)
test['fill_runtimeMinutes_Bruno'].unique()
# Out:
# videoGame
# array([2.10e+01, 1.00e+02, 6.80e+01, 3.00e+01, 9.00e+01, 8.10e+01,
#        2.30e+01, 1.29e+02, 9.60e+01, 1.00e+00, 9.10e+01, 8.40e+01,
#        7.90e+01, 6.00e+01, 8.90e+01, 9.30e+01, 1.42e+02, 1.50e+01,
#        1.01e+02, 9.70e+01, 2.50e+01, 8.30e+01, 2.20e+01, 6.70e+01,
#        1.60e+02, 1.08e+02, 9.40e+01, 1.02e+02, 3.40e+01, 5.00e+01,
#        1.05e+02, 2.60e+01, 7.00e+01, 4.50e+01, 3.00e+00, 1.70e+01,
#        4.20e+01, 9.90e+01, 5.20e+01, 8.80e+01,      nan, 9.80e+01,
#        5.90e+01, 8.70e+01, 5.70e+01, 1.00e+01, 4.10e+01, 3.10e+01,
#        6.00e+00, 1.10e+01, 9.50e+01, 1.28e+02, 2.04e+02, 1.40e+01,
#        2.90e+01, 4.60e+01, 8.50e+01, 1.80e+01, 1.20e+01, 4.40e+01,
#        4.70e+01, 1.22e+02, 4.00e+00, 9.20e+01, 8.20e+01, 4.90e+01,
#        1.30e+01, 1.17e+02, 1.60e+01, 7.20e+01, 7.40e+01, 1.19e+02,
#        1.40e+02, 7.50e+01, 1.15e+02, 2.80e+01, 7.60e+01, 7.30e+01,
#        7.70e+01, 6.90e+01, 5.00e+00, 1.30e+02, 1.68e+02, 4.00e+01,
# ...

# %%
# train.to_csv('pp_train.csv', index=False)
# test.to_csv('pp_test.csv', index=False)

# %%
# from support.df_init import init

# df = init()
# df
import pandas as pd

df = pd.read_csv('pp_train.csv')
df
# Out:
#                                  originalTitle  rating  startYear  endYear  \
# 0      Neogenic Nightmare Chapter 3: Hydro-Man       8       1995   1995.0
# 1                                      Looping       6       1982   1982.0
# 2                               Idealnaya para       6       1992   1992.0
# 3                  MasterChef Celebrity México       6       2021      NaN
# 4                                  Seutateueob       8       2020   2020.0
# ...                                        ...     ...        ...      ...
# 16426                                 Caprices       6       1942   1942.0
# 16427                                Haar Jeet       5       1990   1990.0
# 16428                              Kotigobba 3       6       2021   2021.0
# 16429                       Ator l'invincibile       4       1982   1982.0
# 16430                        Anniversary Night      10       2022   2022.0
#
# ...

# %%
df.columns
# Out:
# Index(['originalTitle', 'rating', 'startYear', 'endYear', 'runtimeMinutes',
#        'awardWins', 'numVotes', 'totalImages', 'totalVideos', 'totalCredits',
#        'criticReviewsTotal', 'titleType', 'awardNominationsExcludeWins',
#        'canHaveEpisodes', 'isAdult', 'numRegions', 'userReviewsTotal',
#        'is_Documentary', 'is_History', 'is_Adventure', 'is_Thriller',
#        'is_Game-Show', 'is_Comedy', 'is_Sci-Fi', 'is_Romance', 'is_Biography',
#        'is_Musical', 'is_Western', 'is_Music', 'is_Film-Noir', 'is_Adult',
#        'is_Reality-TV', 'is_News', 'is_Action', 'is_Crime', 'is_Short',
#        'is_Fantasy', 'is_Family', 'is_Mystery', 'is_Talk-Show', 'is_Drama',
#        'is_Sport', 'is_War', 'is_Horror', 'is_Animation',
#        'fill_runtimeMinutes', 'is_from_Oceania', 'is_from_North America',
#        'is_from_South America', 'is_from_Asia', 'is_from_Africa',
#        'is_from_Europe', 'countryOfOrigin', 'countryOfOrigin_freq_enc',
# ...

# %%
df.loc[(df['is_Short'] == 1) & (df['canHaveEpisodes'] == 1), 'titleType']
# Out:
# 1344         tvSeries
# 1402         tvSeries
# 3582         tvSeries
# 3759         tvSeries
# 3980         tvSeries
# 4401     tvMiniSeries
# 4814         tvSeries
# 5091         tvSeries
# 6160         tvSeries
# 8829         tvSeries
# 10348    tvMiniSeries
# 10844        tvSeries
# 11105    tvMiniSeries
# 11478        tvSeries
# 12483        tvSeries
# Name: titleType, dtype: object
